# %%
import streamlit as st
from io import BytesIO
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('mercari_shops_transaction_data.csv')
df
# Out:
#              date  member_id  order_number                store_id  \
# 0      2025/06/16    3968385  M25061603453  UL8Vkevja8kTGdnZXZMdB4
# 1      2025/06/11    2560742  M25061111760  oioPDeGW7aK9rs9U6M5gJT
# 2      2025/07/04    5279701  M25070409884  kiMfWr6KRzTdVgrVKoVfTg
# 3      2025/07/29    3012464  M25072902813  sQaykhxWwnoxkzeqmVvNd8
# 4      2025/07/23    4379960  M25072308765  P9R5s5HwNyCBJVBQxFLFBP
# ...           ...        ...           ...                     ...
# 20523  2025/07/09    3644667  M25070900295  d2uUKgmbjTGT7BzBGUnXxe
# 20524  2025/07/17    3834091  M25071710216  d2uUKgmbjTGT7BzBGUnXxe
# 20525  2025/06/24     389323  M25062410091  nB5s7MPxA2juj3JocGGi4V
# 20526  2025/06/19    4723482  M25061901025  YoUQXX6TT8X6C47LxjRZbH
# 20527  2025/06/25      28280  M25062502345  YoUQXX6TT8X6C47LxjRZbH
#
#                 store_name                                          item_name  \
# 0                 トクトクshop        VARIVAS(バリバス) ライン キャスティングMAXパワーX8 300m 4号 0
# 1       Parts shop BRIGHTZ                  タウンエースバン S403M S413M フロントウィンカーカバー
# 2                 ロンロゼショップ  ゼブラ ジェルボールペン サラサクリップ 0.5 ビンテージ 10色 JJ15-10C-VI...
# 3            レディースファッション専門  バスボム ギフト おもちゃ 子供 キャラクター おもちゃ入り バスボール プレゼント 誕生日...
# 4                FIND shop  SHIMANO シマノ Deore XT CN-HG93 チェーン 118リンク 9スピード...
# ...                    ...                                                ...
# 20523            MANDARAKE  集英社 2014年(平成26年)の漫画雑誌 週刊少年ジャンプ 2014年(平成26年)47 ...
# 20524            MANDARAKE                                    月刊少年エース 2000/08
# 20525  もりもりショップ　インボイス登録事業者  8- POPEYE　ポパイ (1981.10/25)　提案！ドレスダウンを気にしたい 200185
# 20526             駿河屋メルカリ店              【中古】コミック雑誌 週刊少年ジャンプ 1989年6月12日号 No.26
# 20527             駿河屋メルカリ店                       【中古】ゲーム雑誌 週刊ファミ通 2022年6月30日号
#
#       category_name_1 category_name_2 category_name_3 country  expenditure
# 0                スポーツ         マリンスポーツ       ウインドサーフィン     スイス         5637
# 1           車・バイク・自転車               車             パーツ      台湾         9350
# 2           ハンドメイド・手芸     雑貨・ステーショナリー             その他    アメリカ         1375
# 3        キッチン・日用品・その他        タオル・バス用品             タオル    アメリカ         2690
# 4                スポーツ      ストリート系スポーツ             その他      韓国         3260
# ...               ...             ...             ...     ...          ...
# 20523         本・雑誌・漫画              雑誌          男性コミック    フランス         1210
# 20524         本・雑誌・漫画              雑誌          男性コミック    アメリカ         5720
# 20525         本・雑誌・漫画              雑誌             その他    イギリス          500
# 20526         本・雑誌・漫画              雑誌          男性コミック     カナダ         1170
# 20527         本・雑誌・漫画              雑誌             ゲーム    オランダ          500
#
# [20528 rows x 11 columns]

# %%
# Generate the text for word cloud
text = " ".join(df['item_name'].astype(str))

# %%
wc = WordCloud(width=800, height=400, background_color="white").generate(text)
fig, ax = plt.subplots(figsize=(10, 5))
ax.axis("off")

# 显示 WordCloud
st.title("Hot items Word Cloud")
st.image(wc.to_array())
# Out:
# 2025-08-06 17:52:48.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-06 17:52:48.308 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-06 17:52:48.309 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-06 17:52:48.349 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-06 17:52:48.366 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-06 17:52:48.366 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-08-06 17:52:48.366 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
